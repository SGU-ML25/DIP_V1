# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
    # for filename in filenames:
        # print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %cd /kaggle/working/
# !rmdir /kaggle/working/DIP
# !rm -rf /kaggle/working/DIP_V1
! git clone https://github.com/SGU-ML25/DIP_V1.git
# %cd DIP_V1
# %pwd
# Out:
# /kaggle/working
# Cloning into 'DIP_V1'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 19 (delta 2), reused 15 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 29.79 MiB | 35.80 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /kaggle/working/DIP_V1
# '/kaggle/working/DIP_V1'

# %%
# import os
# from huggingface_hub import snapshot_download

# # Tạo thư mục data nếu chưa có
# os.makedirs("data", exist_ok=True)

# print("Đang tải dataset từ Hugging Face...")
# snapshot_download(
#     repo_id="solozy/DIP", 
#     repo_type="dataset", 
#     local_dir="data",
#     local_dir_use_symlinks=False
# )
# print("Tải dataset thành công!")

# %%
import os 
import sys
import torch
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output

sys.path.append(os.getcwd())
from src.utils import Config
from src.train import train
from src.evaluate import evaluate

    # DATA_ROOT = "./data/"
    # CATEGORIES = ["bottle", "cable", "capsule", "carpet", "grid", "hazelnut", "leather", "metal_nut", "pill", "screw", "tile", "toothbrush", "transistor", "wood", "zipper"]
    # IMG_SIZE = 256
    # PATCH_SIZE = 4
    # BATCH_SIZE = 4
    # LR_AE = 1e-4
    # LR_PRED = 2e-4
    # LR_RL = 1e-5
    # BETA_START = 1.0
    # BETA_END = 0.1
    # EPOCHS = 50     # Giảm từ 100 xuống 50
    # DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    # NUM_WORKERS = 4 # Tận dụng đa nhân CPU để load ảnh

Config.EPOCHS = 50
Config.DATA_ROOT = "/kaggle/input/datasets/ipythonx/mvtec-ad"
Config.CATEGORY = "bottle"
Config.BATCH_SIZE = 32
Config.DEVICE = "cuda:1"
Config.IMG_SIZE = 256
print(f"IMG_SIZE: {Config.IMG_SIZE}")
print(f"PATCH_SIZE: {Config.PATCH_SIZE}")
print(f"BATCH_SIZE: {Config.BATCH_SIZE}")
print(f"Epoch: {Config.EPOCHS}")
torch.cuda.empty_cache()
# Out:
# IMG_SIZE: 256
# PATCH_SIZE: 16
# BATCH_SIZE: 32
# Epoch: 50

# %%
# print(Config.DATA_ROOT)
# data_path = Config.DATA_ROOT
# print(f"Danh sách nội dung trong {data_path}:")
# print(os.listdir(data_path))
print(f"--- Bắt đầu ---")
train(Config.CATEGORY)
print("✅ Huấn luyện hoàn tất!")
# Out:
# --- Bắt đầu ---
# Starting training for bottle on cuda:1...
# Calculating category template...
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 188MB/s]
# Epoch 0/50 | Beta: 1.00 | Reward: 1.0159 | AE Loss: 0.258323 | Pred Loss: 0.715970
# Epoch 1/50 | Beta: 0.98 | Reward: 1.0036 | AE Loss: 0.123966 | Pred Loss: 0.619424
# Epoch 2/50 | Beta: 0.96 | Reward: 0.9897 | AE Loss: 0.080786 | Pred Loss: 0.440204
# Epoch 3/50 | Beta: 0.95 | Reward: 0.9678 | AE Loss: 0.056542 | Pred Loss: 0.283193
# Epoch 4/50 | Beta: 0.93 | Reward: 0.9402 | AE Loss: 0.045770 | Pred Loss: 0.089465
# Epoch 5/50 | Beta: 0.91 | Reward: 0.9203 | AE Loss: 0.042760 | Pred Loss: 0.044644
# Epoch 6/50 | Beta: 0.89 | Reward: 0.8908 | AE Loss: 0.035619 | Pred Loss: 0.036052
# Epoch 7/50 | Beta: 0.87 | Reward: 0.8748 | AE Loss: 0.027749 | Pred Loss: 0.028971
# Epoch 8/50 | Beta: 0.86 | Reward: 0.8559 | AE Loss: 0.027934 | Pred Loss: 0.031214
# Epoch 9/50 | Beta: 0.84 | Reward: 0.8381 | AE Loss: 0.027055 | Pred Loss: 0.026343
# Epoch 10/50 | Beta: 0.82 | Reward: 0.8116 | AE Loss: 0.022732 | Pred Loss: 0.024709
# Epoch 11/50 | Beta: 0.80 | Reward: 0.8019 | AE Loss: 0.020252 | Pred Loss: 0.026454
# Epoch 12/50 | Beta: 0.78 | Reward: 0.7784 | AE Loss: 0.019337 | Pred Loss: 0.023540
# Epoch 13/50 | Beta: 0.77 | Reward: 0.7610 | AE Loss: 0.019440 | Pred Loss: 0.022448
# Epoch 14/50 | Beta: 0.75 | Reward: 0.7356 | AE Loss: 0.017560 | Pred Loss: 0.023550
# Epoch 15/50 | Beta: 0.73 | Reward: 0.7292 | AE Loss: 0.017767 | Pred Loss: 0.021066
# Epoch 16/50 | Beta: 0.71 | Reward: 0.7028 | AE Loss: 0.016898 | Pred Loss: 0.019121
# Epoch 17/50 | Beta: 0.69 | Reward: 0.6819 | AE Loss: 0.015396 | Pred Loss: 0.020725
# Epoch 18/50 | Beta: 0.68 | Reward: 0.6568 | AE Loss: 0.014752 | Pred Loss: 0.022064
# Epoch 19/50 | Beta: 0.66 | Reward: 0.6390 | AE Loss: 0.012856 | Pred Loss: 0.019308
# Epoch 20/50 | Beta: 0.64 | Reward: 0.6189 | AE Loss: 0.011475 | Pred Loss: 0.021134
# Epoch 21/50 | Beta: 0.62 | Reward: 0.6027 | AE Loss: 0.011514 | Pred Loss: 0.018751
# Epoch 22/50 | Beta: 0.60 | Reward: 0.5886 | AE Loss: 0.012350 | Pred Loss: 0.018379
# Epoch 23/50 | Beta: 0.59 | Reward: 0.5696 | AE Loss: 0.008372 | Pred Loss: 0.015369
# Epoch 24/50 | Beta: 0.57 | Reward: 0.5562 | AE Loss: 0.009105 | Pred Loss: 0.018946
# Epoch 25/50 | Beta: 0.55 | Reward: 0.5271 | AE Loss: 0.008091 | Pred Loss: 0.017972
# Epoch 26/50 | Beta: 0.53 | Reward: 0.5240 | AE Loss: 0.006914 | Pred Loss: 0.018077
# Epoch 27/50 | Beta: 0.51 | Reward: 0.4946 | AE Loss: 0.007182 | Pred Loss: 0.018427
# Epoch 28/50 | Beta: 0.50 | Reward: 0.4780 | AE Loss: 0.005821 | Pred Loss: 0.018288
# Epoch 29/50 | Beta: 0.48 | Reward: 0.4560 | AE Loss: 0.005598 | Pred Loss: 0.016396
# Epoch 30/50 | Beta: 0.46 | Reward: 0.4363 | AE Loss: 0.008742 | Pred Loss: 0.017968
# Epoch 31/50 | Beta: 0.44 | Reward: 0.4163 | AE Loss: 0.007044 | Pred Loss: 0.018842
# Epoch 32/50 | Beta: 0.42 | Reward: 0.4020 | AE Loss: 0.006682 | Pred Loss: 0.014962
# Epoch 33/50 | Beta: 0.41 | Reward: 0.3824 | AE Loss: 0.007236 | Pred Loss: 0.016219
# Epoch 34/50 | Beta: 0.39 | Reward: 0.3656 | AE Loss: 0.006075 | Pred Loss: 0.018113
# Epoch 35/50 | Beta: 0.37 | Reward: 0.3547 | AE Loss: 0.007952 | Pred Loss: 0.016914
# Epoch 36/50 | Beta: 0.35 | Reward: 0.3274 | AE Loss: 0.006845 | Pred Loss: 0.014597
# Epoch 37/50 | Beta: 0.33 | Reward: 0.3123 | AE Loss: 0.005586 | Pred Loss: 0.013799
# Epoch 38/50 | Beta: 0.32 | Reward: 0.3003 | AE Loss: 0.005678 | Pred Loss: 0.016307
# Epoch 39/50 | Beta: 0.30 | Reward: 0.2739 | AE Loss: 0.007062 | Pred Loss: 0.017783
# Epoch 40/50 | Beta: 0.28 | Reward: 0.2588 | AE Loss: 0.006467 | Pred Loss: 0.017877
# Epoch 41/50 | Beta: 0.26 | Reward: 0.2486 | AE Loss: 0.005157 | Pred Loss: 0.016731
# Epoch 42/50 | Beta: 0.24 | Reward: 0.2272 | AE Loss: 0.005412 | Pred Loss: 0.014854
# Epoch 43/50 | Beta: 0.23 | Reward: 0.2093 | AE Loss: 0.007835 | Pred Loss: 0.015878
# Epoch 44/50 | Beta: 0.21 | Reward: 0.1994 | AE Loss: 0.006413 | Pred Loss: 0.016628
# Epoch 45/50 | Beta: 0.19 | Reward: 0.1750 | AE Loss: 0.005786 | Pred Loss: 0.014126
# Epoch 46/50 | Beta: 0.17 | Reward: 0.1590 | AE Loss: 0.004833 | Pred Loss: 0.012934
# Epoch 47/50 | Beta: 0.15 | Reward: 0.1430 | AE Loss: 0.003880 | Pred Loss: 0.013843
# Epoch 48/50 | Beta: 0.14 | Reward: 0.1244 | AE Loss: 0.003890 | Pred Loss: 0.016335
# Epoch 49/50 | Beta: 0.12 | Reward: 0.1091 | AE Loss: 0.006369 | Pred Loss: 0.016805
# Training completed and models saved.
# ✅ Huấn luyện hoàn tất!

# %%
# !mkdir results

print(f"--- Đang đánh giá trên tập Test của {Config.CATEGORY} ---")
evaluate(Config.CATEGORY)

# Load và chạy thêm script test toàn bộ ảnh lỗi đã viết trước đó
from IPython.display import display, Image
print("\n--- Đang thực hiện kiểm thử trên TOÀN BỘ ảnh lỗi ---")

def show_top_results(category, num=20):
    res_dir = f"results"
    images = sorted([f for f in os.listdir(res_dir) if f.startswith(f"{category}_dial_")], key=lambda x: os.path.getmtime(os.path.join(res_dir, x)), reverse=True)
    for img in images[:num]:
        print(f"Kết quả chẩn đoán: {img}")
        display(Image(filename=os.path.join(res_dir, img)))
        print("-" * 80)

show_top_results(Config.CATEGORY)
# Out:
# --- Đang đánh giá trên tập Test của bottle ---
# Evaluating category: bottle with Advanced DIP & Template-Aware Models...
# Running enhanced inference...
#
# --- Industrial Template-Aware Metrics for bottle ---
# Pixel-level AUC: 0.5208
# Pixel-level F1-max: 0.1328
#
# --- Đang thực hiện kiểm thử trên TOÀN BỘ ảnh lỗi ---
